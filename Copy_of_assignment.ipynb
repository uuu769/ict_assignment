# %% [markdown]
# <a href="https://colab.research.google.com/github/uuu769/ict_assignment/blob/main/Copy_of_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
i1= float (input("Enter item1 price :"))
iq1= int(input("Enter item1 quantity:"))
i2= float (input("Enter item2 price :"))
iq2= int(input("Enter item2 quqntity:"))
total_bill = i1*iq1+i2*iq2
print("Total bill :",total_bill)
# Out:
# Enter item1 price :5
# Enter item1 quantity:5
# Enter item2 price :10
# Enter item2 quqntity:10
# Total bill : 125.0

# %%
c= int(input("Enter celsius :"))
f=(c* 9/5) + 3  2
print("Temperature in Fahrenheit:",f)
# Out:
# Enter celsius :30
# Temperature in Fahrenheit: 86.0

# %%
s=int(input("Enter basic salary :"))
total= s*0.2+0.1*s+s
print("Net salary :",total)
# Out:
# Enter basic salary :20000
# Net salary : 26000.0

# %%
p=int(input("Principal :"))
r=int(input("Rate of Interest :"))
t=int(input("Time (in years) :"))
si=(p*r*t)/100
print("simple interest :",si)
# Out:
# Principal :10000
# Rate of Interest :5
# Time (in years) :2
# simple interest : 1000.0

# %%
m=int(input("Enter total minutes :"))
h=m//60
mi=m%60
print(h,"hours and",mi,"minutes")
# Out:
# Enter total minutes :130
# 2 hours and 10 minutes

# %%
w=int(input("Enter the weight(kg) :"))
h=float(input("Height(m) :"))
bmi=w/(h*h)
print("BMI :",bmi)
# Out:
# Enter the weight(kg) :60
# Height(m) :1.65
# BMI : 22.03856749311295

# %%
o=int(input("Enter Original price :"))
m=0.10*o
x=o-m
print("Discounted Price :",x)
# Out:
# Enter Original price :1200
# Discounted Price : 1080.0

# %%
from IPython.core.display import Math
s1=int(input("Enter first side :"))
s2=int(input("Enter second side :"))
s3=int(input("Enter third side :"))
s=(s1+s2+s3)/2
import math
area=math.sqrt(s*(s-s1)*(s-s2)*(s-s3))
print("Area of a tringle :",area)
# Out:
# Enter first side :5
# Enter second side :6
# Enter third side :7
# Area of a tringle : 14.696938456699069

# %%
p=int(input("Enter wall length (in meters) :"))
d=int(input("Enter wall height (in meters) :"))
window_area=1.5*1.2
wall_area=p*d
paint_area=wall_area-window_area
cost=paint_area*25
print("Total area to be painted :",paint_area)
print("Total cost :",cost)
# Out:
# Enter wall length (in meters) :12
# Enter wall height (in meters) :8
# Total area to be painted : 94.2
# Total cost : 2355.0

# %%
a=float(input("Enter number of unit consumed :"))
f=100
rate=a*5.2
total_bill=rate+100
print("Electricity bill :",total_bill)
# Out:
# Enter number of unit consumed :250
# Electricity bill : 1400.0
